# %%
#project 1
#simi services
import tkinter as tk
from tkinter import messagebox
from PIL import Image

def welcomeMessage(amount):
    #create a tkinter window
    window = tk.Toplevel(root)
    window.title("Reciept Box")
    window.geometry("500x200")
    
    label_1 = tk.Label(window, text="This is Simi Services Python GUI with Tkinter By Adekunle Gold")
    label_1.pack()
    label_2 = tk.Label(window, text=f"Your delivery fee is {amount}")
    label_2.pack()
    
    #run the Tkinter event loop
    root.mainloop()

def submit():
    username = username_entry.get()
    location = location_entry.get()
    weight = weight_entry.get()
    
    if location == "Ibeju-Lekki community" and weight >= "10kg":
        amount = "N5,000"
        welcomeMessage(amount)
    if location == "Ibeju-Lekki community" and weight <= "10kg":
        amount = "N3,500"
        welcomeMessage(amount)
    if location == "Epe" and weight >= "10kg":
        amount = "N5,000"
        welcomeMessage(amount)
    if location == "Epe" and weight <= "10kg":
        amount = "N10,000"
        welcomeMessage(amount)
    else:
        messagebox.showerror("Sorry", "We are not able to offer our servies...")

#create main window
root = tk.Tk()
root.title("Login Form")
root.geometry("500x200")

#create username label and entry
username_label = tk.Label(root, text="Username: ")
username_label.pack()
username_entry = tk.Entry(root)
username_entry.pack()

#create username label and entry
location_label = tk.Label(root, text="LOCATION: ")
location_label.pack()
location_entry = tk.Entry(root)
location_entry.pack()

#create username label and entry
weight_label = tk.Label(root, text="WEIGHT (Kg): ")
weight_label.pack()
weight_entry = tk.Entry(root)
weight_entry.pack()

#create submit button 
submit_button = tk.Button(root, text="ENTER", command=submit)
submit_button.pack()

#run the main event loop
root.mainloop()
